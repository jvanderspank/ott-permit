# %%
## Import Libraries
import pandas as pd
import numpy as np
import calendar
import matplotlib.pyplot as plt
from matplotlib.backends.backend_pdf import PdfPages
import seaborn as sns
from adjustText import adjust_text

# %%
## Load cleaned data
df = pd.read_csv('Permits_by_ELEM_Boundary_Cleaned.csv')

# Sort df by school in NAME column
df = df.sort_values(by='NAME')

# Remove decimal places from DU and convert to integer
df['DU'] = df['DU'].fillna(0).astype(int)

df
# Out:
#                                                  NAME  \
# 0               Assumption Catholic Elementary School
# 101             Assumption Catholic Elementary School
# 102             Assumption Catholic Elementary School
# 103             Assumption Catholic Elementary School
# 104             Assumption Catholic Elementary School
# ...                                               ...
# 19939  Thomas D'Arcy McGee Catholic Elementary School
# 19938  Thomas D'Arcy McGee Catholic Elementary School
# 19937  Thomas D'Arcy McGee Catholic Elementary School
# 19951  Thomas D'Arcy McGee Catholic Elementary School
# 19936  Thomas D'Arcy McGee Catholic Elementary School
#
#                            B_NAME    CATEGORY          ADDRESS_1    YEAR  \
# 0               Assumption School  Elementary     80 BARRETTE ST  2016.0
# 101             Assumption School  Elementary      280 LEVIS AVE  2021.0
# 102             Assumption School  Elementary    10 MCARTHUR AVE  2021.0
# 103             Assumption School  Elementary  263 GREENSWAY AVE  2021.0
# 104             Assumption School  Elementary     163 LONGPRE ST  2021.0
# ...                           ...         ...                ...     ...
# 19939  Thomas d'Arcy McGee School  Elementary  567 TAKAMOSE PRIV  2020.0
# 19938  Thomas d'Arcy McGee School  Elementary  545 TAKAMOSE PRIV  2020.0
# 19937  Thomas d'Arcy McGee School  Elementary  523 TAKAMOSE PRIV  2020.0
# 19951  Thomas d'Arcy McGee School  Elementary   507 PIMIWIDON ST  2021.0
# 19936  Thomas d'Arcy McGee School  Elementary      455 WANAKI RD  2020.0
#
#            MONTH  DU     PLAN          BLG_TYPE  \
# 0          April   1      101            Single
# 101          May   3      238         Apartment
# 102          May  10      239         Apartment
# 103         June  74      NaN         Apartment
# 104         July   2      471   Semi - Detached
# ...          ...  ..      ...               ...
# 19939  September  20   4M1581  Stacked Rowhouse
# 19938  September  20  4M-1581  Stacked Rowhouse
# 19937  September  20  4M-1581  Stacked Rowhouse
# 19951    January   4  4M-1651          Rowhouse
# 19936     August   8  4M-1581         Apartment
#
#                             CONTRACTOR  \
# 0           OTTAWA GENERAL CONTRACTORS
# 101                 CONTRACTOR UNKNOWN
# 102                 CONTRACTOR UNKNOWN
# 103                 CONTRACTOR UNKNOWN
# 104                 CONTRACTOR UNKNOWN
# ...                                ...
# 19939  MATTAMY DEVELOPMENT CORPORATION
# 19938            MATTAMY HOMES LIMITED
# 19937        MATTAMY (ROCKCLIFFE) INC.
# 19951  UNIFORM URBAN DEVELOPMENTS LTD.
# 19936               CONTRACTOR UNKNOWN
#
#                                              DESCRIPTION
# 0      Interior alterations to the kitchen and exteri...
# 101                         Construct a 3 storey triplex
# 102    Construct a 3 storey apartment building (10 Un...
# 103    Construct a 6 storey apartment building with u...
# 104    Construct a 3 storey semi-detached dwelling wi...
# ...                                                  ...
# 19939  Construct a 3 storey block of 20 stacked dwell...
# 19938      Construct a 3 storey 20 unit stacked dwelling
# 19937      Construct a 3 storey 20 unit stacked dwelling
# 19951  Construct a 2 storey block of 4 rowhouse dwell...
# 19936            Construct a 3 storey apartment building
#
# [23872 rows x 11 columns]

# %%
# Pivot the data to have years as columns and schools as rows
du_pivot = df.pivot_table(values='DU', index='NAME', columns='YEAR', aggfunc='sum', fill_value=0)

# Display the pivoted table
du_pivot
# Out:
# YEAR                                            2016.0  2017.0  2018.0  \
# NAME
# Assumption Catholic Elementary School               17     200     105
# Chapel Hill Catholic Elementary School               3       0       2
# Convent Glen Catholic Elementary School              2       8       7
# Corpus Christi Catholic Elementary School          730     221     606
# Divine Infant Catholic Elementary School            95     218      86
# ...                                                ...     ...     ...
# St. Rose of Lima Catholic Elementary School          0       0       1
# St. Stephen Catholic Elementary School             154     302     330
# St. Theresa Catholic Elementary School              24      17      36
# St. Thomas More Catholic Elementary School           0       0       0
# Thomas D'Arcy McGee Catholic Elementary School       7       3      19
#
# YEAR                                            2019.0  2020.0  2021.0  \
# NAME
# Assumption Catholic Elementary School              255      43     189
# Chapel Hill Catholic Elementary School               5       0      34
# Convent Glen Catholic Elementary School             10       4       0
# Corpus Christi Catholic Elementary School          676    1298     679
# Divine Infant Catholic Elementary School           275      84     282
# ...                                                ...     ...     ...
# St. Rose of Lima Catholic Elementary School          0       1       2
# St. Stephen Catholic Elementary School             114       7     310
# St. Theresa Catholic Elementary School              31      27      57
# St. Thomas More Catholic Elementary School           0       2       0
# Thomas D'Arcy McGee Catholic Elementary School     171     218     353
#
# YEAR                                            2022.0  2023.0  2024.0
# NAME
# Assumption Catholic Elementary School              549      80      20
# Chapel Hill Catholic Elementary School               3       0       0
# Convent Glen Catholic Elementary School             20       3       0
# Corpus Christi Catholic Elementary School         1036      66       6
# Divine Infant Catholic Elementary School           433      29       1
# ...                                                ...     ...     ...
# St. Rose of Lima Catholic Elementary School          0       1       0
# St. Stephen Catholic Elementary School             266      86       2
# St. Theresa Catholic Elementary School             278      45       1
# St. Thomas More Catholic Elementary School           0       1       1
# Thomas D'Arcy McGee Catholic Elementary School     351       3       0
#
# [71 rows x 9 columns]

# %%
def analyze_permit_data(df):
    """
    Analyzes permit data by grouping it by name, year, and month, and calculating the sum of DU.
    Then, it creates a pivot table with the sum of DU values for each name and year, grouped by month.
    The pivot table is then reindexed to have the columns in the desired order.
    
    Parameters:
    - df (DataFrame): The input DataFrame containing the permit data.
    
    Returns:
    - du_by_month_pivot (DataFrame): The pivot table with the corrected order of columns.
    """
    
    # Group the data by name, year, and month and calculate the sum of DU
    du_by_month = df.groupby(['NAME', 'YEAR', 'MONTH'])['DU'].sum().reset_index()
    
    # Create a pivot table with the sum of DU values for each name and year, grouped by month
    du_by_month_pivot = du_by_month.pivot_table(values='DU', index=['NAME', 'YEAR'], columns='MONTH', aggfunc='sum', fill_value=0)
    
    # Calculate the total sum of DU for each name and year
    du_by_month_pivot['Total'] = du_by_month_pivot.sum(axis=1)
    
    # Define the desired order of the columns
    desired_order = ['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December', 'Total']
    
    # Reindex the columns of the du_by_month_pivot DataFrame
    du_by_month_pivot = du_by_month_pivot.reindex(columns=desired_order)
    
    return du_by_month_pivot

# Call the analyze_permit_data function
du_by_month_pivot = analyze_permit_data(df)

# Round the values in the pivot table to 0 decimal places
du_by_month_pivot = du_by_month_pivot.round(0)

# Display the pivot table with the corrected order of columns
du_by_month_pivot.head(50)
# Out:
# MONTH                                                 January  February  \
# NAME                                          YEAR
# Assumption Catholic Elementary School         2016.0        0         0
#                                               2017.0        0         0
#                                               2018.0        1         0
#                                               2019.0        0         0
#                                               2020.0        3         2
#                                               2021.0        0         5
#                                               2022.0        0         4
#                                               2023.0        0        13
#                                               2024.0       20         0
# Chapel Hill Catholic Elementary School        2016.0        0         0
#                                               2018.0        0         0
#                                               2019.0        0         0
#                                               2021.0        0         0
#                                               2022.0        0         0
# Convent Glen Catholic Elementary School       2016.0        0         0
#                                               2017.0        0         1
#                                               2018.0        0         0
#                                               2019.0        0         1
#                                               2020.0        0         0
#                                               2022.0        1         0
#                                               2023.0        0         0
# Corpus Christi Catholic Elementary School     2016.0        8        14
#                                               2017.0       15        10
#                                               2018.0      255       124
#                                               2019.0        3         5
#                                               2020.0      177         2
#                                               2021.0        0         0
#                                               2022.0      197         0
#                                               2023.0        1         0
#                                               2024.0        6         0
# Divine Infant Catholic Elementary School      2016.0        9         8
#                                               2017.0        6         9
#                                               2018.0        0         1
#                                               2019.0        0         2
#                                               2020.0        2         1
#                                               2021.0       10       176
#                                               2022.0        2         7
#                                               2023.0        1         0
#                                               2024.0        1         0
# Dr. F. J. McDonald Catholic Elementary School 2016.0        0         0
#                                               2017.0        1         0
#                                               2018.0        0         1
#                                               2019.0        0         0
#                                               2020.0        0         0
#                                               2021.0        2         0
#                                               2022.0        1         1
#                                               2023.0        0         1
# Georges Vanier Catholic Elementary School     2016.0       12         7
#                                               2018.0        0         0
#                                               2019.0        0        78
#
# MONTH                                                 March  April  May  June  \
# NAME                                          YEAR
# Assumption Catholic Elementary School         2016.0      0      5    1     0
#                                               2017.0      1      2    6     3
#                                               2018.0      0      3    5    27
#                                               2019.0      4      0    8     2
#                                               2020.0      1      0    1    13
#                                               2021.0      0      1   13    74
#                                               2022.0      0      1    1     5
#                                               2023.0     15     12    1     0
#                                               2024.0      0      0    0     0
#                                               2018.0         5    606
#                                               2019.0         3    676
#                                               2020.0         8   1298
#                                               2021.0       170    679
#                                               2022.0         1   1036
#                                               2023.0        23     66
#                                               2024.0         0      6
# Divine Infant Catholic Elementary School      2016.0         5     95
#                                               2017.0         2    218
#                                               2018.0         3     86
#                                               2019.0         1    275
#                                               2020.0         5     84
#                                               2021.0         1    282
#                                               2022.0       112    433
#                                               2023.0         0     29
#                                               2024.0         0      1
# Dr. F. J. McDonald Catholic Elementary School 2016.0         0      2
#                                               2017.0         0      3
#                                               2018.0         0      5
#                                               2019.0         1      4
#                                               2020.0         0      4
#                                               2021.0         1      8
#                                               2022.0         0     11
#                                               2023.0        33     40
# Georges Vanier Catholic Elementary School     2016.0        79    310
#                                               2018.0         0    154
#                                               2019.0         0    112

# %%
# Set the style and fonts
plt.style.use('seaborn-whitegrid')
sns.set_context('talk')
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = ['Helvetica', 'Arial']
plt.rcParams['text.color'] = '#333333'

# Custom color for the plot
economist_blue = '#4671A2'

# Define the complete range of years
years = np.arange(2016, 2025)  # 2025 is not included, so this is 2016-2024

# Create a DataFrame to hold the full range of years, ensuring each school has entries for all years
full_years_df = pd.DataFrame(years, columns=['YEAR'])

# Create a PDF file to save the figures
with PdfPages('school_du_reports.pdf') as pdf:
    # Iterate over each school in the DataFrame
    for school in df['NAME'].unique():
        # Filter the DataFrame for the current school
        school_df = df[df['NAME'] == school]

        # Aggregate DU values by YEAR to ensure unique YEAR entries
        agg_school_df = school_df.groupby('YEAR')['DU'].sum().reset_index()

        # Merge aggregated data with the full years DataFrame to ensure all years are represented
        merged_df = pd.merge(full_years_df, agg_school_df, on='YEAR', how='left')
        merged_df.fillna(0, inplace=True)  # Fill missing DU values with 0

        # Plot the data as a bar chart
        plt.figure(figsize=(10, 6))
        plt.bar(merged_df['YEAR'], merged_df['DU'], color=economist_blue)

        # Add data labels
        for x, y in zip(merged_df['YEAR'], merged_df['DU']):
            plt.text(x, y, f'{int(y)}', ha='center', va='bottom')

        # Set title and labels
        plt.title(f'Sum of DU by YEAR - {school}', fontsize=20, color='#333333')
        plt.xlabel('YEAR', fontsize=16, color='#333333')
        plt.ylabel('Sum of DU', fontsize=16, color='#333333')
        
        # Customize ticks
        plt.xticks(years, rotation=45, fontsize=14, color='#333333')
        plt.yticks(fontsize=14, color='#333333')
        
        # Customize gridlines
        plt.grid(True, which='major', linestyle='--', linewidth=0.5, color='grey', axis='y')
        
        # Instead of showing the plot, save it to the PDF
        pdf.savefig()  # saves the current figure into the pdf
        plt.close()  # close the figure to free memory
# Out:
# C:\Users\e38282\AppData\Local\Temp\ipykernel_15324\1937739335.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %%
# Save the dataframe to an Excel workbook
#with pd.ExcelWriter('Permits by Elementary Boundary.xlsx') as writer:
#    du_by_month_pivot.to_excel(writer, sheet_name='Summary')
